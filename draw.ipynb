# %% [markdown]
# <a href="https://colab.research.google.com/github/xyzz1223/nbviewerTest/blob/master/draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 导入必要的库
import matplotlib.pyplot as plt
import numpy as np

# 在 Notebook 中显示图形的魔法命令
# %matplotlib inline

# 创建数据
x = np.linspace(0, 10, 100)  # 从0到10的100个点
y = np.sin(x)  # 正弦函数

# 创建图形
plt.figure(figsize=(8, 4))  # 设置图形大小
plt.plot(x, y, label='sin(x)', color='blue', linestyle='-', linewidth=2)

# 添加标题和标签
plt.title('Simple Sine Wave', fontsize=16)
plt.xlabel('X-axis', fontsize=12)
plt.ylabel('Y-axis', fontsize=12)

# 添加图例和网格
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# 显示图形
plt.show()
